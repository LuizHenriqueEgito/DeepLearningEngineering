# %%
import torch
import torch.nn as nn
from torch import Tensor

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import make_circles
from sklearn.model_selection import train_test_split

# %%
device = torch.cuda.is

# %%
SEED = 42
TEST_SIZE = 0.2
N_SAMPLES = 500_000

# %%
X, y = make_circles(N_SAMPLES, random_state=SEED, noise=0.05, factor=0.3)

# %%
X_train, X_test, y_train, y_tes = train_test_split(
    X,
    y,
    shuffle=True,
    stratify=y,
    random_state=SEED,
    test_size=TEST_SIZE
)

# %%
SAMPLE = 15_000
fig, ax = plt.subplots()
ax.scatter(
    X_train[:SAMPLE, 0],
    X_train[:SAMPLE, 1],
    c=y_train[:SAMPLE],
    alpha=0.4,
    cmap='seismic'
)
ax.grid(True, linestyle=':')
ax.set_xlabel('X1')
ax.set_ylabel('X2')
ax.set_title('Features')
plt.show()

# %%
X_train, X_test = torch.tensor(X_train, dtype)
y_train, y_test =
