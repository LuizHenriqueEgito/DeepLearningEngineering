# %%
from pathlib import Path

# %%
from utils.dataset import DefaultCredit

# %%
TRAIN_FILE = Path('dataset/df_train.pq')
TEST_FILE = Path('dataset/df_test.pq')

# %%
train_dataset = DefaultCredit(TRAIN_FILE)
test_dataset = DefaultCredit(TEST_FILE)

# %%
print('Tamanho dos Datasets')
print(f'{len(train_dataset)=:_}')
print(f'{len(test_dataset)=:_}')
# Out:
# Tamanho dos Datasets
# len(train_dataset)=24_000
# len(test_dataset)=6_000

# %%
train_dataset[6]
# Out:
# (tensor([[ 7.0670e+03,  0.0000e+00, -1.0000e+00,  1.0000e+05],
#          [-4.1800e+02,  7.4820e+03, -1.0000e+00,  1.0000e+05],
#          [ 7.0640e+03,  1.5315e+04, -1.0000e+00,  1.0000e+05],
#          [ 1.5229e+04,  9.7050e+03, -1.0000e+00,  1.0000e+05],
#          [ 9.6890e+03,  0.0000e+00, -1.0000e+00,  1.0000e+05],
#          [ 2.6690e+03,  4.6000e+03,  0.0000e+00,  1.0000e+05]]),
#  tensor(0.))

# %%
test_dataset[6]
# Out:
# (tensor([[ 7.1280e+03,  0.0000e+00,  1.0000e+00,  1.1000e+05],
#          [ 1.8520e+03,  1.0000e+03,  2.0000e+00,  1.1000e+05],
#          [ 2.6250e+03,  0.0000e+00,  0.0000e+00,  1.1000e+05],
#          [ 2.6250e+03,  0.0000e+00,  0.0000e+00,  1.1000e+05],
#          [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  1.1000e+05],
#          [ 0.0000e+00,  0.0000e+00, -2.0000e+00,  1.1000e+05]]),
#  tensor(1.))
